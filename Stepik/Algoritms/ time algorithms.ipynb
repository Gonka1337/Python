# %% [markdown]
# # истинные математических утверждений:

# %% [markdown]
# n^6 + 3n ∈ Θ( n^6)

# %% [markdown]
# 2^n + 12 ∈ Θ( 2^n )

# %% [markdown]
# 3^n + 2^n ∈ Θ( 3^n )

# %% [markdown]
# n^n + n ∈ Θ( n^n )

# %%
import math
n=100000

# %%
 print(math.log(n, 2) ** (math.log(n, 2)))
# Out:
# 1.8609928418609558e+20

# %%
print(n ** (math.log(n, 2)))
# Out:
# 1.1173838040692942e+83

# %%
print(math.log(math.log(n, 2)))
# Out:
# 2.8099832782637204

# %%
 print(math.sqrt(math.log(n, 4)))
# Out:
# 2.8818085011357724

# %%
print(math.log(n, 3))
# Out:
# 10.479516371446921

# %%
print(math.log(n, 2) ** 2)
# Out:
# 275.88015669004955

# %%
print(math.sqrt(n))
# Out:
# 316.22776601683796

# %%
 print(n / math.log(n, 5))
# Out:
# 13979.400086720374

# %%
print(math.log(math.factorial(n),2))
# Out:
# 1516704.173924289

# %%
print(3 ** math.log(n, 2))
# Out:
# 84103196.75493282

# %%
 print(n ** 2)
# Out:
# 10000000000

# %%
 print(7 ** (math.log(n, 2)))
# Out:
# 108836510811282.69

# %%
print(2 ** n)
# Out:
# ...

# %%
print(4 ** n)
# Out:
# ...

# %%
print(2 ** (3 * n))
# Out:
# ...

# %%
print(math.factorial(n))

# %%
print(2 ** (2 ** n))

# %%
print(n ** (math.sqrt(n)))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-51-ac2eadaeec75> in <module>
# ----> 1 print(n ** (math.sqrt(n)))
#
# OverflowError: (34, 'Result too large')

# %%
math.log(n, 2) ** (math.log(n, 2))>4 ** n
# Out:
# False

# %%
2 ** (2 ** n)>math.factorial(n)

# %%
import math
n=100000
print(math.log(math.log(n, 2)))
print(math.sqrt(math.log(n, 4)))
print(math.log(n, 3))
print(math.log(n, 2) ** 2)
print(math.sqrt(n))
print(n / math.log(n, 5))
print(math.log(math.factorial(n),2))
print(3 ** math.log(n, 2))
print(n ** 2)
print(7 ** (math.log(n, 2)))
print(math.log(n, 2) ** (math.log(n, 2)))
# Out:
# 2.8099832782637204
# 2.8818085011357724
# 10.479516371446921
# 275.88015669004955
# 316.22776601683796
# 13979.400086720374
# 1516704.173924289
# 84103196.75493282
# 10000000000
# 108836510811282.69
# 1.8609928418609558e+20
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-7-337d907d9827> in <module>
#      12 print(7 ** (math.log(n, 2)))
#      13 print(math.log(n, 2) ** (math.log(n, 2)))
# ---> 14 print(n ** (math.sqrt(n)))
#
# OverflowError: (34, 'Result too large')

# %%
print(n ** (math.sqrt(n)))
print(n ** (math.log(n, 2)))
print(2 ** n)
print(4 ** n)
print(2 ** (3 * n))
print(math.factorial(n))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-5-2ba92cc24176> in <module>
# ----> 1 print(n ** (math.sqrt(n)))
#       2 print(n ** (math.log(n, 2)))
#       3 print(2 ** n)
#       4 print(4 ** n)
#       5 print(2 ** (3 * n))
#
# OverflowError: (34, 'Result too large')

# %%
math.log(n, 2) ** (math.log(n, 2))>7 ** (math.log(n, 2))
# Out:
# True

# %%
print(math.log(math.log(n, 2)))
print(math.sqrt(math.log(n, 4)))
print(math.log(n, 3))
print(math.log(n, 2) ** 2)
print(math.sqrt(n))
print(n / math.log(n, 5))
print(math.log(math.factorial(n),2))
print(3 ** math.log(n, 2))
print(n ** 2)
print(7 ** (math.log(n, 2)))
print(math.log(n, 2) ** (math.log(n, 2)))
print(n ** (math.log(n, 2)))
print(n ** (math.sqrt(n)))
print(2 ** n)
print(4 ** n)
print(2 ** (3 * n))
print(math.factorial(n))
